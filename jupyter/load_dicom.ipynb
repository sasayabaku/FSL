# %%
import pydicom

# %%
import matplotlib.pyplot as plt

# %%
horizontal = pydicom.dcmread('./data/dcm/horizontal.dcm')
coronal = pydicom.dcmread('./data/dcm/coronal.dcm')
sagittal = pydicom.dcmread('./data/dcm/sagittal.dcm')

# %%
plt.imshow(sagittal.pixel_array, cmap=plt.cm.bone)
# plt.imsave('./horizontal.svg', ds.pixel_array, cmap=plt.cm.bone, format='svg')

# %%
plt.imshow(horizontal.pixel_array, cmap=plt.cm.bone)

# %%
plt.imshow(coronal.pixel_array, cmap=plt.cm.bone)
