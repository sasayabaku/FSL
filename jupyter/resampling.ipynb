# %%
from nilearn import image as nilimg

# %%
data = '/Users/sasayabaku/PAT00008'

# %%
import os

dir_list = os.listdir(data)

# %%
from nilearn.datasets import load_mni152_template

# %%
template = load_mni152_template()

# %%
image = nilimg.load_img(os.path.join(data, '20180106_0854303DGEIRSAGs016a1000.nii'))

# %%
from nilearn.image import resample_to_img

# %%
resampled_img = resample_to_img(image, template)
# Out:
# /Users/sasayabaku/.pyenv/versions/3.6.0/lib/python3.6/site-packages/nilearn/image/resampling.py:518: UserWarning: Casting data from int16 to float32
#   warnings.warn("Casting data from %s to %s" % (data.dtype.name, aux))

# %%
print(resampled_img.shape)
print(image.shape)
print(template.shape)
# Out:
# (91, 109, 91)
# (256, 256, 170)
# (91, 109, 91)

# %%
from nilearn import plotting

# %%
plotting.plot_anat(image)
# Out:
# /Users/sasayabaku/.pyenv/versions/3.6.0/lib/python3.6/site-packages/nilearn/image/resampling.py:518: UserWarning: Casting data from int32 to float32
#   warnings.warn("Casting data from %s to %s" % (data.dtype.name, aux))

# %%
plotting.plot_anat(resampled_img)

# %%
plotting.plot_anat(template)
